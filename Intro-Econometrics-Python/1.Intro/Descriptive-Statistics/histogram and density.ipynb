# %% [markdown]
# # Continuous Distributions: Histogram and Density
#
# For this example, we'll plot the distribution of return on equity (ROE) variable found in the CEO salary dataset.

# %%
import wooldridge as wool
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
ceo_salary = wool.dataWoo('ceosal1')

# %%
ceo_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salary    209 non-null    int64
#  1   pcsalary  209 non-null    int64
#  2   sales     209 non-null    float64
#  3   roe       209 non-null    float64
#  4   pcroe     209 non-null    float64
#  5   ros       209 non-null    int64
#  6   indus     209 non-null    int64
#  7   finance   209 non-null    int64
#  8   consprod  209 non-null    int64
#  9   utility   209 non-null    int64
#  10  lsalary   209 non-null    float64
#  11  lsales    209 non-null    float64
# dtypes: float64(5), int64(7)
# memory usage: 19.7 KB

# %%
# extract roe from dataset 
roe = ceo_salary.roe

# %%
# histogram with counts
plt.hist(roe, color='blue')
plt.ylabel('Counts')
plt.xlabel('ROE');

# %%
# histogram with density and manual break
breaks = [0, 5, 10, 20, 30, 60]
plt.hist(row, color='red', bins=breaks, density=True)
plt.ylabel('Density')
plt.xlabel('ROE');

# %% [markdown]
# <br>To generate a kernel density plot, we use the statsmodels module.

# %%
# algorithm to estimate kernel density
kde = sm.nonparametric.KDEUnivariate(roe)
kde.fit();

# %%
# plot kernel density 
plt.plot(kde.support, kde.density, color='black', linewidth=2)
plt.ylabel('density')
plt.xlabel('roe');

# %%
# kernely density with overlayed histogram 
plt.hist(row, color='blue', density=True)
plt.plot(kde.support, kde.density, color='red', linewidth=2)
plt.ylabel('density')
plt.xlabel('roe');
